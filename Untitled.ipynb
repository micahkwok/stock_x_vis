# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('StockX-Data-Contest-2019-3.xlsx', sheet_name = 1)
# Out:
# <ipython-input-6-09b16c9662da>:1: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   data = pd.read_excel('StockX-Data-Contest-2019-3.xlsx', sheet_name = 1)

# %%
data.head()
# Out:
#   Order Date   Brand                                   Sneaker Name  \
# 0 2017-09-01   Yeezy           Adidas-Yeezy-Boost-350-Low-V2-Beluga
# 1 2017-09-01   Yeezy    Adidas-Yeezy-Boost-350-V2-Core-Black-Copper
# 2 2017-09-01   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-Green
# 3 2017-09-01   Yeezy       Adidas-Yeezy-Boost-350-V2-Core-Black-Red
# 4 2017-09-01   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
#
#    Sale Price  Retail Price Release Date  Shoe Size  Buyer Region
# 0      1097.0           220   2016-09-24       11.0    California
# 1       685.0           220   2016-11-23       11.0    California
# 2       690.0           220   2016-11-23       11.0    California
# 3      1075.0           220   2016-11-23       11.5      Kentucky
# 4       828.0           220   2017-02-11       11.0  Rhode Island

# %%
data.groupby(['Sneaker Name']).mean().sort_values(by = ['Sale Price'], ascending = False)
# Out:
#                                                     Sale Price  Retail Price  \
# Sneaker Name
# Air-Jordan-1-Retro-High-Off-White-White            1826.068894           190
# Air-Jordan-1-Retro-High-Off-White-Chicago          1769.800000           190
# Adidas-Yeezy-Boost-350-Low-Turtledove              1531.661765           200
# Nike-Air-Presto-Off-White                          1236.055369           160
# Adidas-Yeezy-Boost-350-Low-Oxford-Tan              1011.514286           200
# Adidas-Yeezy-Boost-350-Low-Moonrock                 996.710000           200
# Adidas-Yeezy-Boost-350-Low-Pirate-Black-2016        984.237705           200
# Nike-Air-Force-1-Low-Virgil-Abloh-Off-White-AF100   975.516129           150
# Adidas-Yeezy-Boost-350-V2-Core-Black-Red            937.754967           220
# Adidas-Yeezy-Boost-350-Low-Pirate-Black-2015        895.094737           200
# Nike-Air-Max-97-Off-White-Elemental-Rose-Queen      893.782407           190
# ...
